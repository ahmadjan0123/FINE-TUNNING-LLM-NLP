# %% [markdown]
# <h1>Importing Libraries </h1>

# %%
from transformers import pipeline

# %% [markdown]
# <h1>CREATING THE MODEL</h1>

# %%
predict_next_word = pipeline(
    'fill-mask',
    model = 'bert-base-uncased'
)
# Out:
# Loading weights: 100%|██████████| 202/202 [00:00<00:00, 2465.46it/s]
# [transformers] BertForMaskedLM LOAD REPORT from: bert-base-uncased
# Key                         | Status     |  |
# ----------------------------+------------+--+-
# cls.seq_relationship.weight | UNEXPECTED |  |
# bert.pooler.dense.weight    | UNEXPECTED |  |
# bert.pooler.dense.bias      | UNEXPECTED |  |
# cls.seq_relationship.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %% [markdown]
# <h1>GENERATION</h1>

# %%
result = predict_next_word(
    'The capital of france is[MASK].'
)

# %%
for r in result:
    print(r['token_str'],': ',r['score'])
# Out:
# paris :  0.4167897403240204
# lille :  0.07141660898923874
# lyon :  0.0633925274014473
# marseille :  0.04444747790694237
# tours :  0.030297135934233665
